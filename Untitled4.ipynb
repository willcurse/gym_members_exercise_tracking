# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.linear_model import LinearRegression
sns.set(style='whitegrid')

# %% [markdown]
# # 1-: DATA COLLECTION

# %% [markdown]
# # 1.1 Loading Dataset

# %%
data=pd.read_csv(r'C:\Users\Administrator\Desktop\DA-jupyter\gym_members_exercise_tracking.csv')
data
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %% [markdown]
# # 2-:DATA CLEANING

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            973 non-null    int64
#  1   Gender                         973 non-null    object
#  2   Weight (kg)                    973 non-null    float64
#  3   Height (m)                     973 non-null    float64
#  4   Max_BPM                        973 non-null    int64
#  5   Avg_BPM                        973 non-null    int64
#  6   Resting_BPM                    973 non-null    int64
#  7   Session_Duration (hours)       973 non-null    float64
#  8   Calories_Burned                973 non-null    float64
#  9   Workout_Type                   973 non-null    object
#  10  Fat_Percentage                 973 non-null    float64
#  11  Water_Intake (liters)          973 non-null    float64
# ...

# %%
#checking for empty value
data.isnull().sum()
# Out:
# Age                              0
# Gender                           0
# Weight (kg)                      0
# Height (m)                       0
# Max_BPM                          0
# Avg_BPM                          0
# Resting_BPM                      0
# Session_Duration (hours)         0
# Calories_Burned                  0
# Workout_Type                     0
# Fat_Percentage                   0
# Water_Intake (liters)            0
# Workout_Frequency (days/week)    0
# Experience_Level                 0
# BMI                              0
# dtype: int64

# %%
data.describe()
# Out:
#               Age  Weight (kg)  Height (m)     Max_BPM     Avg_BPM  \
# count  973.000000   973.000000   973.00000  973.000000  973.000000
# mean    38.683453    73.854676     1.72258  179.883864  143.766701
# std     12.180928    21.207500     0.12772   11.525686   14.345101
# min     18.000000    40.000000     1.50000  160.000000  120.000000
# 25%     28.000000    58.100000     1.62000  170.000000  131.000000
# 50%     40.000000    70.000000     1.71000  180.000000  143.000000
# 75%     49.000000    86.000000     1.80000  190.000000  156.000000
# max     59.000000   129.900000     2.00000  199.000000  169.000000
#
#        Resting_BPM  Session_Duration (hours)  Calories_Burned  Fat_Percentage  \
# count   973.000000                973.000000       973.000000      973.000000
# mean     62.223022                  1.256423       905.422405       24.976773
# std       7.327060                  0.343033       272.641516        6.259419
# ...

# %% [markdown]
# # 3-: Data Analysis

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Weight (kg)', 'Height (m)', 'Max_BPM', 'Avg_BPM',
#        'Resting_BPM', 'Session_Duration (hours)', 'Calories_Burned',
#        'Workout_Type', 'Fat_Percentage', 'Water_Intake (liters)',
#        'Workout_Frequency (days/week)', 'Experience_Level', 'BMI'],
#       dtype='object')

# %% [markdown]
# # 3.1 Distribution of Age

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=data,x='Age',hue='Gender',multiple='stack',bins=30,kde=True,)
plt.title("Distribution of Age")
plt.xlabel('Number of Review')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# # 3.2 Distribution of BMI

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=data,kde=True,color='red',x='BMI',hue="Gender",multiple='stack')
plt.title('Distribution of BMI')
plt.xlabel('set axis')
plt.ylabel('bmi')
plt.show()

# %% [markdown]
# # 3.3 Calories burned by workout type

# %%
sns.boxplot(x='Workout_Type',y='Calories_Burned',data=data, palette="coolwarm")
plt.title('Calories burned by workout type')
plt.xlabel('workout')
plt.ylabel('calories')
plt.show()

# %% [markdown]
# # 3.4 Relationship between workout frequency and session duration

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='Workout_Frequency (days/week)',y='Session_Duration (hours)',hue='Gender',data=data)
plt.title('Relationship between workout frequency and session duration')
plt.xlabel('Workout Frequency..')
plt.ylabel('Session duration')
plt.show()

# %% [markdown]
# # 3.5 Calories burned vs. experience level

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Weight (kg)', 'Height (m)', 'Max_BPM', 'Avg_BPM',
#        'Resting_BPM', 'Session_Duration (hours)', 'Calories_Burned',
#        'Workout_Type', 'Fat_Percentage', 'Water_Intake (liters)',
#        'Workout_Frequency (days/week)', 'Experience_Level', 'BMI'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Experience_Level', y='Calories_Burned', data=data, palette="cool" )
plt.title(' Calories burned vs. experience level')
plt.xlabel('Calories')
plt.ylabel('Exprience')
plt.show()

# %% [markdown]
# # 3.6 How does body fat percentage vary across different age groups?

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Weight (kg)', 'Height (m)', 'Max_BPM', 'Avg_BPM',
#        'Resting_BPM', 'Session_Duration (hours)', 'Calories_Burned',
#        'Workout_Type', 'Fat_Percentage', 'Water_Intake (liters)',
#        'Workout_Frequency (days/week)', 'Experience_Level', 'BMI'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Age', y='Fat_Percentage', data=data, palette="muted")
plt.title("Body Fat Percentage Across Different Age Groups")
plt.xlabel("Age Group")
plt.ylabel("Body Fat Percentage")
plt.show()

# %% [markdown]
# # 3.7 What is the average resting heart rate of gym members, and how does it differ by workout frequency or experience level?

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Weight (kg)', 'Height (m)', 'Max_BPM', 'Avg_BPM',
#        'Resting_BPM', 'Session_Duration (hours)', 'Calories_Burned',
#        'Workout_Type', 'Fat_Percentage', 'Water_Intake (liters)',
#        'Workout_Frequency (days/week)', 'Experience_Level', 'BMI'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Resting_BPM',y='Workout_Frequency (days/week)',data=data)
plt.title('average resting heart rate of gym members, and how does it differ by workout frequency or experience level')
plt.xlabel('Resting bpm')
plt.ylabel('Workout frequeny')
plt.show()

# %% [markdown]
# # 3.8 What is the average height and weight of members, and is there a relationship between these variables and their workout preferences?

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Weight (kg)', 'Height (m)', 'Max_BPM', 'Avg_BPM',
#        'Resting_BPM', 'Session_Duration (hours)', 'Calories_Burned',
#        'Workout_Type', 'Fat_Percentage', 'Water_Intake (liters)',
#        'Workout_Frequency (days/week)', 'Experience_Level', 'BMI'],
#       dtype='object')

# %%
avg_height=data['Height (m)'].mean()
avg_weight=data['Weight (kg)'].mean()
height_and_weight_group=data.groupby('Workout_Type').agg({'Height (m)':'mean','Weight (kg)':'mean'}).reset_index()
print(f'Average height is, {avg_height} m ')
print(f'Average weight is, {avg_weight} kg')
print(f'Group height and weight is {height_and_weight_group}')
# Out:
# Average height is, 1.7225796505652622 m
# Average weight is, 73.85467625899281 kg
# Group height and weight is   Workout_Type  Height (m)  Weight (kg)
# 0       Cardio    1.719529    74.841176
# 1         HIIT    1.719367    74.628054
# 2     Strength    1.716705    72.187597
# 3         Yoga    1.735146    73.886611

# %%
#height
plt.figure(figsize=(5,3))
sns.boxplot(x='Workout_Type',y='Height (m)',data=data)
plt.title('Height boxplot visual')
plt.show()

#weight
plt.figure(figsize=(5,3))
sns.boxplot(x='Workout_Type',y='Weight (kg)',data=data)
plt.title('Weight boxplot visual')
plt.show()

#relationship....between both
plt.figure(figsize=(10,6))
sns.scatterplot(x='Height (m)',y='Weight (kg)',hue='Workout_Type',data=data)
plt.title('relationship....between both height and weight')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %% [markdown]
# # 3.9 Which workout type is most popular among gym members? Does it differ between males and females?

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Weight (kg)', 'Height (m)', 'Max_BPM', 'Avg_BPM',
#        'Resting_BPM', 'Session_Duration (hours)', 'Calories_Burned',
#        'Workout_Type', 'Fat_Percentage', 'Water_Intake (liters)',
#        'Workout_Frequency (days/week)', 'Experience_Level', 'BMI'],
#       dtype='object')

# %%
most_popular=data['Workout_Type'].value_counts().idxmax()
print(most_popular)

workout_gender=data.groupby(['Gender','Workout_Type']).size()
print(workout_gender)

plt.figure(figsize=(10,6))
sns.countplot(x='Workout_Type',hue='Gender',data=data)
plt.title("most popular among gym members")
plt.show()
# Out:
# Strength
# Gender  Workout_Type
# Female  Cardio          126
#         HIIT            107
#         Strength        123
#         Yoga            106
# Male    Cardio          129
#         HIIT            114
#         Strength        135
#         Yoga            133
# dtype: int64

# %% [markdown]
# #  3.10 Do members who work out more frequently burn more calories per session?

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Weight (kg)', 'Height (m)', 'Max_BPM', 'Avg_BPM',
#        'Resting_BPM', 'Session_Duration (hours)', 'Calories_Burned',
#        'Workout_Type', 'Fat_Percentage', 'Water_Intake (liters)',
#        'Workout_Frequency (days/week)', 'Experience_Level', 'BMI'],
#       dtype='object')

# %%
group=data.groupby('Workout_Frequency (days/week)')['Calories_Burned'].mean().reset_index()
print(group)

plt.figure(figsize=(5,3))
sns.scatterplot(x='Workout_Frequency (days/week)',y='Calories_Burned',data=data)
plt.title("more frequently burn more calories per session?")
plt.xlabel('Workout_Frequency')
plt.ylabel('Calories_Burned')
plt.show()

plt.figure(figsize=(5,3))
sns.scatterplot(x='Calories_Burned',y='Workout_Frequency (days/week)',data=data)
plt.title("more frequently burn more calories per session?")
plt.xlabel('Calories_Burned')
plt.ylabel('Workout_Frequency ')
plt.show()
# Out:
#    Workout_Frequency (days/week)  Calories_Burned
# 0                              2       726.380711
# 1                              3       821.437500
# 2                              4       997.640523
# 3                              5      1277.568627

# %% [markdown]
# # 3.11 What are the most common workout types for different experience levels?

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Weight (kg)', 'Height (m)', 'Max_BPM', 'Avg_BPM',
#        'Resting_BPM', 'Session_Duration (hours)', 'Calories_Burned',
#        'Workout_Type', 'Fat_Percentage', 'Water_Intake (liters)',
#        'Workout_Frequency (days/week)', 'Experience_Level', 'BMI'],
#       dtype='object')

# %%
data=data.groupby('Workout_Type')['Experience_Level'].mean().reset_index()
print(data)

plt.figure(figsize=(10,6))
sns.barplot(x='Workout_Type',y='Experience_Level',data=data)
plt.title(' most common workout types for different experience levels')
plt.xlabel('Workout_Type')
plt.ylabel('Experience_Level')
plt.show()
# Out:
#   Workout_Type  Experience_Level
# 0       Cardio          1.745098
# 1         HIIT          1.837104
# 2     Strength          1.798450
# 3         Yoga          1.866109
